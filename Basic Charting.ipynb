# %%
# %matplotlib notebook

# %%
import matplotlib as mpl
mpl.get_backend()
# Out:
# u'nbAgg'

# %%
import matplotlib.pyplot as plt
plt.plot?

# %%
plt.plot(3,2)
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
plt.plot(3,2,'.')

# %%
from matplotlib.backends.backend_agg import FigureCanvasAgg
from matplotlib.figure import Figure
fig = Figure()
canvas = FigureCanvasAgg(fig)
ax = fig.add_subplot(111)
ax.plot(3,2,'.')
canvas.print_png('test.png')

# %%
# %%html
# <img src="test.png"/>
# Out:
# <img src="test.png"/>

# %%
plt.figure()
plt.plot(3,2,'o')
ax = plt.gca()
ax.axis([0, 6, 0, 10])
# Out:
# <img src="data:image/png;base64,..." width="432">
# [0, 6, 0, 10]

# %%
plt.figure()
plt.plot(1.5, 1.5, 'o')
plt.plot(2,2,'o')
plt.plot(2.5,2.5,'o')
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
ax = plt.gca()
ax.get_children()
# Out:
# [<matplotlib.lines.Line2D at 0x879de80>,
#  <matplotlib.lines.Line2D at 0x85ebe48>,
#  <matplotlib.lines.Line2D at 0x878c048>,
#  <matplotlib.spines.Spine at 0x8606c50>,
#  <matplotlib.spines.Spine at 0x8606828>,
#  <matplotlib.spines.Spine at 0x872dc50>,
#  <matplotlib.spines.Spine at 0x872d438>,
#  <matplotlib.axis.XAxis at 0x81930b8>,
#  <matplotlib.axis.YAxis at 0x878c240>,
#  <matplotlib.text.Text at 0x879d278>,
#  <matplotlib.text.Text at 0x87b5860>,
#  <matplotlib.text.Text at 0x87b5588>,
#  <matplotlib.patches.Rectangle at 0x87b55c0>]
